# %%
# %load main.py
import argparse
from midi2audio import FluidSynth
import tensorflow as tf
import os
import numpy as np
from model import GenreLSTM
import mido
import midi_util
from mido import MidiFile
# %matplotlib inline

import matplotlib
import numpy as np
import matplotlib.pyplot as plt
def setup_dir():
    

    print('[*] Setting up directory...')

    main_path = "./runs"
    current_run = os.path.join(main_path, "test")

    files_path = "./data"
    files_path = os.path.join(files_path, "test")

    x_path = os.path.join(files_path, 'inputs')
    y_path = os.path.join(files_path, 'velocities')
    eval_path = os.path.join(files_path, 'eval')

    model_path = os.path.join(current_run, 'model')
    logs_path = os.path.join(current_run, 'tmp')
    png_path = os.path.join(current_run, 'png')
    pred_path = os.path.join(current_run, 'predictions')

    if not os.path.exists(current_run):
        os.makedirs(current_run)
    if not os.path.exists(logs_path):
        os.makedirs(logs_path)
    if not os.path.exists(model_path):
        os.makedirs(model_path)
    if not os.path.exists(png_path):
        os.makedirs(png_path)
    if not os.path.exists(pred_path):
        os.makedirs(pred_path)

    dirs = {
            'main_path': main_path,
            'current_run': current_run,
            'model_path': model_path,
            'logs_path': logs_path,
            'png_path': png_path,
            'eval_path': eval_path,
            'pred_path': pred_path,
            'x_path': x_path,
            'y_path': y_path
        }

    # print main_path
    # print current_run
    # print model_path
    # print logs_path
    # print png_path
    # print eval_path
    # print x_path
    # print y_path
    return dirs


fs = FluidSynth('~/sf.sf2')

# %%
def plot_evaluation(epoch, filename, c_out, j_out, e_out, out_list, path=True):
    fig = plt.figure(figsize=(14,11), dpi=120)
    fig.suptitle(filename, fontsize=10, fontweight='bold')

    graph_items = [out_list[-1]*120, c_out[-1]*120, j_out[-1]*120,  (c_out[-1]-j_out[-1])*120 , e_out[-1]]
    plots = len(graph_items)
    cmap = ['jet', 'jet', 'jet', 'jet', 'bwr']
    vmin = [0,0,0,-10,-1]
    vmax = [120,120,120,10,1]
    names = ["Actual", "Classical", "Jazz", "Difference", "Encoded"]


    for i in xrange(0, plots):
        fig.add_subplot(1,plots,i+1)
        plt.imshow(graph_items[i], vmin=vmin[i], vmax=vmax[i], cmap=cmap[i], aspect='auto')

        a = plt.colorbar(aspect=80)
        a.ax.tick_params(labelsize=7)
        ax = plt.gca()
        ax.xaxis.tick_top()

        if i == 0:
            ax.set_ylabel('Time Step')
        ax.xaxis.set_label_position('top')
        ax.tick_params(axis='both', labelsize=7)
        fig.subplots_adjust(top=0.85)
        ax.set_title(names[i], y=1.09)
        # plt.tight_layout()

    plt.xlim(0,88)

    if not path:
        out_png = os.path.join(self.dirs['png_path'], filename.split('.')[0] + "-e%d" % (epoch)+".png")
        plt.savefig(out_png, bbox_inches='tight')
        plt.close(fig)
    else:
#         out_png = os.path.join(path) + "predict.png")
#         plt.savefig(path, bbox_inches='tight')
        plt.show()

# %%
dirs = setup_dir()
network  = GenreLSTM(dirs, input_size=176, mini=True, bi=True)
network.prepare_model()
# Out:
# [*] Setting up directory...
# [*] Preparing bidirectional dynamic RNN...
# INFO:tensorflow:Summary name Jazz error is illegal; using Jazz_error instead.
# INFO:tensorflow:Summary name Classical error is illegal; using Classical_error instead.
# INFO:tensorflow:Summary name Average error is illegal; using Average_error instead.
# INFO:tensorflow:Summary name Jazz negation is illegal; using Jazz_negation instead.
# INFO:tensorflow:Summary name Classical negation is illegal; using Classical_negation instead.

# %%
network.load("a", path="/Users/Iman/Desktop/models/model/model-e212.ckpt")
# Out:
#  [*] Loading checkpoint...

# %%
import file_util

# %%
file_util.validate_data("/Users/Iman/Desktop/models/mid/",4)
file_util.quantize_data("/Users/Iman/Desktop/models/mid_valid/",4)
file_util.save_data("/Users/Iman/Desktop/models/mid_valid_quantized/", 4, one_hot=True)
# Out:
# Processed 0 files out of 0
# Processed 0 files out of 0
#
# Processed 0 files out of 0

# %%
input_dir = "/Users/Iman/Desktop/models/inputs/"
output_dir = "/Users/Iman/Desktop/models/velocities/"
jazz_names = []
classical_names = []

# %%
for i, filename in enumerate(os.listdir(os.path.join(input_dir, "jazz"))):
    if filename.split(".")[-1] == "npy":
        jazz_names.append(filename)

        
for i, filename in enumerate(os.listdir(os.path.join(input_dir, "classical"))):
    if filename.split(".")[-1] == "npy":
        classical_names.append(filename)
# c_error, c_out, j_out, e_out, out_list = network.predict("/Users/Iman/Desktop/models/mid_valid_quantized_inputs/n2.mid.npy", "/Users/Iman/Desktop/models/mid_valid_quantized_velocities/n2.mid.npy")

# %%
print classical_names
print jazz_names
# Out:
# ['beethoven_les_adieux_2_format0.mid.npy', 'burg_gewitter_format0.mid.npy', 'chpn-p23_format0.mid.npy', 'chpn_op25_e1_format0.mid.npy', 'debussy_cc_5_format0.mid.npy', 'franceschetti02.mid.npy', 'K570 Piano Sonata 2mov.mid.npy', 'LEE_J02.mid.npy', 'pavane.mid.npy', 'rac_op3_2_format0.mid.npy', 'reflect.mid.npy', 'schu_143_1_format0.mid.npy', 'TET01.mid.npy', 'UENO01.mid.npy', 'victoria03.mid.npy', 'waldstein_1_format0.mid.npy', 'YOO01.mid.npy', 'ZHOU01.mid.npy']
# ['alfiepno.mid.npy', 'Autumn In NY.mid.npy', 'Effendi - McCoy Tyner.mid.npy', 'Falling Grace .mid.npy', 'INVITATION.mid.npy', 'My Romance.mid.npy', 'NoMoreBlues.mid.npy', 'Remember - solo jazz piano.mid.npy', 'Renewaltrio.mid.npy', 'SammyWalked.mid.npy', 'Speak Low (Doug McKenzie).mid.npy', 'taketheatrain.mid.npy', 'Very Early solo piano.mid.npy', 'Warmvalleysolo.mid.npy', 'WhyDoILoveYou.mid.npy', 'xmas.mid.npy', 'YBSN2CH2.mid.npy', 'Zingaro - Jobim.mid.npy']

# %%
for filename in classical_names:
    print filename
    name = filename.split(".")[0] + ".mid"
    classical_input = os.path.join("/Users/Iman/Desktop/models/inputs/classical", filename)
    classical_velocities = os.path.join("/Users/Iman/Desktop/models/velocities/classical", filename)
    c_error, c_out, j_out, e_out, out_list = network.predict(classical_input, classical_velocities)
#     plot_evaluation(1, "n2", c_out, j_out, e_out, out_list)
    mid = MidiFile(os.path.join("/Users/Iman/Desktop/models/predict/original/classical/", name))
    classical = midi_util.stylify(mid, c_out[-1], 4)
    classical.save(os.path.join("/Users/Iman/Desktop/models/predict/original_classical/classical/", name))
    
    mid = MidiFile(os.path.join("/Users/Iman/Desktop/models/predict/original/classical/", name))
    jazz = midi_util.stylify(mid, j_out[-1], 4)
    jazz.save(os.path.join("/Users/Iman/Desktop/models/predict/original_classical/jazz/", name))
# Out:
# beethoven_les_adieux_2_format0.mid.npy
# burg_gewitter_format0.mid.npy
# chpn-p23_format0.mid.npy
# chpn_op25_e1_format0.mid.npy
# debussy_cc_5_format0.mid.npy
# franceschetti02.mid.npy
# K570 Piano Sonata 2mov.mid.npy
# LEE_J02.mid.npy
# pavane.mid.npy
# rac_op3_2_format0.mid.npy
# reflect.mid.npy
# schu_143_1_format0.mid.npy
# TET01.mid.npy
# UENO01.mid.npy
# victoria03.mid.npy
# waldstein_1_format0.mid.npy
# YOO01.mid.npy
# ZHOU01.mid.npy

# %%
for filename in jazz_names:
    print filename
    name = filename.split(".")[0] + ".mid"
    jazz_input = os.path.join("/Users/Iman/Desktop/models/inputs/jazz", filename)
    jazz_velocities = os.path.join("/Users/Iman/Desktop/models/velocities/jazz", filename)
    c_error, c_out, j_out, e_out, out_list = network.predict(jazz_input, jazz_velocities)
    mid = MidiFile(os.path.join("/Users/Iman/Desktop/models/predict/original/jazz/", name))
    classical = midi_util.stylify(mid, c_out[-1], 4)
#     plot_evaluation(0, "filename", c_out, j_out, e_out, out_list)
    classical.save(os.path.join("/Users/Iman/Desktop/models/predict/original_jazz/classical/", name))
    mid = MidiFile(os.path.join("/Users/Iman/Desktop/models/predict/original/jazz/", name))
    jazz = midi_util.stylify(mid, j_out[-1], 4)
    jazz.save(os.path.join("/Users/Iman/Desktop/models/predict/original_jazz/jazz/", name))
# Out:
# alfiepno.mid.npy
# Autumn In NY.mid.npy
# Effendi - McCoy Tyner.mid.npy
# Falling Grace .mid.npy
# INVITATION.mid.npy
# My Romance.mid.npy
# NoMoreBlues.mid.npy
# Remember - solo jazz piano.mid.npy
# Renewaltrio.mid.npy
# SammyWalked.mid.npy
# Speak Low (Doug McKenzie).mid.npy
# taketheatrain.mid.npy
# Very Early solo piano.mid.npy
# Warmvalleysolo.mid.npy
# WhyDoILoveYou.mid.npy
# xmas.mid.npy
# YBSN2CH2.mid.npy
# Zingaro - Jobim.mid.npy

# %%
# np.save("/Users/Iman/Desktop/models/jazz_out.npy", j_out)

# %%
# mid = MidiFile("/Users/Iman/Desktop/models/mid_valid_quantized/n2.mid")
# mid = midi_util.quantize(mid,4)

# %%
# a = midi_util.stylify(mid, c_out[-1], 4)

# %%
# a.save("/Users/Iman/Desktop/models/class_mid.mid")

# %%
# fs.midi_to_audio('input.mid', 'output.wav')

# %%
for filename in classical_names:
#     fs.midi_to_audio('input.mid', 'output.wav')
    print filename
    name = filename.split(".")[0] + ".mid"
    name_m = filename.split(".")[0] + ".wav"

    
    mid_classical = "/Users/Iman/Desktop/models/predict/original_classical/classical/"
    mid_jazz = "/Users/Iman/Desktop/models/predict/original_classical/jazz/"

    output_classical = "/Users/Iman/Desktop/models/predict/original_classical/classical/wav"
    output_jazz = "/Users/Iman/Desktop/models/predict/original_classical/jazz/wav"
    
    c_mp3 = os.path.join(output_classical, name_m)
    j_mp3 = os.path.join(output_jazz, name_m)
    
    c_mid = os.path.join(mid_classical, name)
    j_mid = os.path.join(mid_jazz, name)
    
    fs.midi_to_audio(c_mid, c_mp3)
    fs.midi_to_audio(j_mid, j_mp3)
# Out:
# beethoven_les_adieux_2_format0.mid.npy
# burg_gewitter_format0.mid.npy
# chpn-p23_format0.mid.npy
# chpn_op25_e1_format0.mid.npy
# debussy_cc_5_format0.mid.npy
# franceschetti02.mid.npy
# K570 Piano Sonata 2mov.mid.npy
# LEE_J02.mid.npy
# pavane.mid.npy
# rac_op3_2_format0.mid.npy
# reflect.mid.npy
# schu_143_1_format0.mid.npy
# TET01.mid.npy
# UENO01.mid.npy
# victoria03.mid.npy
# waldstein_1_format0.mid.npy
# YOO01.mid.npy
# ZHOU01.mid.npy

# %%
for filename in jazz_names:
    name = filename.split(".")[0] + ".mid"
    name_m = filename.split(".")[0] + ".wav"

    output_classical = "/Users/Iman/Desktop/models/predict/original_jazz/classical/wav"
    output_jazz = "/Users/Iman/Desktop/models/predict/original_jazz/jazz/wav"

    mid_classical = "/Users/Iman/Desktop/models/predict/original_jazz/classical/"
    mid_jazz = "/Users/Iman/Desktop/models/predict/original_jazz/jazz/"

    c_mp3 = os.path.join(output_classical, name_m)
    j_mp3 = os.path.join(output_jazz, name_m)
    
    c_mid = os.path.join(mid_classical, name)
    j_mid = os.path.join(mid_jazz, name)
    
    fs.midi_to_audio(c_mid, c_mp3)
    fs.midi_to_audio(j_mid, j_mp3)

# %%
jazz_input = "/Users/Iman/Desktop/fri/input.npy"
jazz_velocities = "/Users/Iman/Desktop/fri/output.npy"



# name = filename.split(".")[0] + ".mid"
# jazz_input = os.path.join("/Users/Iman/Desktop/models/inputs/jazz", filename)
# jazz_velocities = os.path.join("/Users/Iman/Desktop/models/velocities/jazz", filename)
c_error, c_out, j_out, e_out, out_list = network.predict(jazz_input, jazz_velocities)
mid = MidiFile("/Users/Iman/Desktop/fri/friday.mid")
classical = midi_util.stylify(mid, j_out[-1], 4)
classical.save("/Users/Iman/Desktop/fri/fri_out_j.mid")

# %%
jazz_input = "/Users/Iman/Desktop/input.npy"
jazz_velocities = "/Users/Iman/Desktop/output.npy"



# name = filename.split(".")[0] + ".mid"
# jazz_input = os.path.join("/Users/Iman/Desktop/models/inputs/jazz", filename)
# jazz_velocities = os.path.join("/Users/Iman/Desktop/models/velocities/jazz", filename)
c_error, c_out, j_out, e_out, out_list = network.predict(jazz_input, jazz_velocities)
mid = MidiFile("/Users/Iman/Desktop/yi.mid")
classical = midi_util.stylify(mid, c_out[-1], 4)
classical.save("/Users/Iman/Desktop/yiruma_c.mid")

# %%
fs.midi_to_audio("/Users/Iman/Desktop/yi.mid", "/Users/Iman/Desktop/yi.wav")
fs.midi_to_audio("/Users/Iman/Desktop/yiruma_c.mid", "/Users/Iman/Desktop/yiruma_c.wav")

myaudio = AudioSegment.from_wav("/Users/Iman/Desktop/yi.wav") 
myaudio = match_target_amplitude(myaudio, -20.0)
myaudio.export("/Users/Iman/Desktop/yi.wav", format="wav")

myaudio = AudioSegment.from_wav("/Users/Iman/Desktop/yiruma_c.wav") 
myaudio = match_target_amplitude(myaudio, -20.0)
myaudio.export("/Users/Iman/Desktop/yiruma_c.wav", format="wav")
# Out:
# <open file '/Users/Iman/Desktop/yiruma_c.wav', mode 'wb+' at 0x116e9cc90>

# %%
# pydub.AudioSegment.ffmpeg = "/Users/Iman/ffmpeg"

c_error, c_out, j_out, e_out, out_list = network.predict(jazz_input, jazz_velocities)
mid = MidiFile("/Users/Iman/Desktop/fri/friday.mid")
classical = midi_util.stylify(mid, c_out[-1], 4)
classical.save("/Users/Iman/Desktop/fri/fri_out_c.mid")

# %%
import pydub
from pydub import AudioSegment
from pydub.utils import make_chunks

    
j_mid_classical = "/Users/Iman/Desktop/models/predict/original_jazz/classical/wav"
j_mid_jazz = "/Users/Iman/Desktop/models/predict/original_jazz/jazz/wav"
c_mid_jazz = "/Users/Iman/Desktop/models/predict/original_classical/jazz/wav"
c_mid_classical = "/Users/Iman/Desktop/models/predict/original_classical/classical/wav"
o_mid_jazz = "/Users/Iman/Desktop/models/predict/original/jazz/wav"
o_mid_classical = "/Users/Iman/Desktop/models/predict/original/classical/wav"

songs = "/Users/Iman/Desktop/models/predict/songs/"

firs = [j_mid_classical, j_mid_jazz, c_mid_jazz, c_mid_classical]
# firs = [o_mid_jazz, o_mid_classical]

# %%
# firs = [o_mid_jazz, o_mid_classical]
dict = {
j_mid_classical : "oc",
j_mid_jazz : "oj",
c_mid_jazz : "oj",
c_mid_classical : "oc",
o_mid_jazz : "aj",
o_mid_classical : "ac"
}

def match_target_amplitude(sound, target_dBFS):
    change_in_dBFS = target_dBFS - sound.dBFS
    return sound.apply_gain(change_in_dBFS)

# %%
directory = o_mid_classical
for folder in firs:
    for filename in os.listdir(folder):
        if filename.split('.')[-1] == "wav": 
            name = filename.split('.')[0]
            path = os.path.join(folder, filename)
            print path
            myaudio = AudioSegment.from_wav(path) 
            chunk_length_ms = 10000 # pydub calculates in millisec
            chunks = make_chunks(myaudio, chunk_length_ms) #Make chunks of one sec

        #Export all of the individual chunks as wav files

            song_path = os.path.join(songs, name)
            if not os.path.exists(song_path):
                os.makedirs(song_path)
            
            
            for i, chunk in enumerate(chunks):
                normalized_chunk = match_target_amplitude(chunk, -20.0)
                chunk_name = os.path.join(song_path, name + "_{0}".format(i) + "_" + dict[folder] + ".wav")
                print "exporting", chunk_name
                normalized_chunk.export(chunk_name, format="wav")
# Out:
# /Users/Iman/Desktop/models/predict/original_jazz/classical/wav/alfiepno.wav
# exporting /Users/Iman/Desktop/models/predict/songs/alfiepno/alfiepno_0_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/alfiepno/alfiepno_1_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/alfiepno/alfiepno_2_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/alfiepno/alfiepno_3_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/alfiepno/alfiepno_4_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/alfiepno/alfiepno_5_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/alfiepno/alfiepno_6_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/alfiepno/alfiepno_7_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/alfiepno/alfiepno_8_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/alfiepno/alfiepno_9_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/alfiepno/alfiepno_10_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/alfiepno/alfiepno_11_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/alfiepno/alfiepno_12_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/alfiepno/alfiepno_13_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/alfiepno/alfiepno_14_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/alfiepno/alfiepno_15_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/alfiepno/alfiepno_16_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/alfiepno/alfiepno_17_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/alfiepno/alfiepno_18_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/alfiepno/alfiepno_19_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/alfiepno/alfiepno_20_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/alfiepno/alfiepno_21_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/alfiepno/alfiepno_22_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/alfiepno/alfiepno_23_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/alfiepno/alfiepno_24_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/alfiepno/alfiepno_25_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/alfiepno/alfiepno_26_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/alfiepno/alfiepno_27_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/alfiepno/alfiepno_28_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/alfiepno/alfiepno_29_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/alfiepno/alfiepno_30_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/alfiepno/alfiepno_31_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/alfiepno/alfiepno_32_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/alfiepno/alfiepno_33_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/alfiepno/alfiepno_34_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/alfiepno/alfiepno_35_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/alfiepno/alfiepno_36_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/alfiepno/alfiepno_37_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/alfiepno/alfiepno_38_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/alfiepno/alfiepno_39_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/alfiepno/alfiepno_40_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/alfiepno/alfiepno_41_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/alfiepno/alfiepno_42_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/alfiepno/alfiepno_43_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/alfiepno/alfiepno_44_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/alfiepno/alfiepno_45_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/alfiepno/alfiepno_46_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/alfiepno/alfiepno_47_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/alfiepno/alfiepno_48_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/alfiepno/alfiepno_49_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/alfiepno/alfiepno_50_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/alfiepno/alfiepno_51_oc.wav
# /Users/Iman/Desktop/models/predict/original_jazz/classical/wav/Autumn In NY.wav
# exporting /Users/Iman/Desktop/models/predict/songs/Autumn In NY/Autumn In NY_0_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/Autumn In NY/Autumn In NY_1_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/Autumn In NY/Autumn In NY_2_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/Autumn In NY/Autumn In NY_3_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/Autumn In NY/Autumn In NY_4_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/Autumn In NY/Autumn In NY_5_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/Autumn In NY/Autumn In NY_6_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/Autumn In NY/Autumn In NY_7_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/Autumn In NY/Autumn In NY_8_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/Autumn In NY/Autumn In NY_9_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/Autumn In NY/Autumn In NY_10_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/Autumn In NY/Autumn In NY_11_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/Autumn In NY/Autumn In NY_12_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/Autumn In NY/Autumn In NY_13_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/Autumn In NY/Autumn In NY_14_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/Autumn In NY/Autumn In NY_15_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/Autumn In NY/Autumn In NY_16_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/Autumn In NY/Autumn In NY_17_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/Autumn In NY/Autumn In NY_18_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/Autumn In NY/Autumn In NY_19_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/Autumn In NY/Autumn In NY_20_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/Autumn In NY/Autumn In NY_21_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/Autumn In NY/Autumn In NY_22_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/Autumn In NY/Autumn In NY_23_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/Autumn In NY/Autumn In NY_24_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/Autumn In NY/Autumn In NY_25_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/Autumn In NY/Autumn In NY_26_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/Autumn In NY/Autumn In NY_27_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/Autumn In NY/Autumn In NY_28_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/Autumn In NY/Autumn In NY_29_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/Autumn In NY/Autumn In NY_30_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/Autumn In NY/Autumn In NY_31_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/Autumn In NY/Autumn In NY_32_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/Autumn In NY/Autumn In NY_33_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/Autumn In NY/Autumn In NY_34_oc.wav
# /Users/Iman/Desktop/models/predict/original_jazz/classical/wav/Effendi - McCoy Tyner.wav
# exporting /Users/Iman/Desktop/models/predict/songs/Effendi - McCoy Tyner/Effendi - McCoy Tyner_0_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/Effendi - McCoy Tyner/Effendi - McCoy Tyner_1_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/Effendi - McCoy Tyner/Effendi - McCoy Tyner_2_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/Effendi - McCoy Tyner/Effendi - McCoy Tyner_3_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/Effendi - McCoy Tyner/Effendi - McCoy Tyner_4_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/Effendi - McCoy Tyner/Effendi - McCoy Tyner_5_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/Effendi - McCoy Tyner/Effendi - McCoy Tyner_6_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/Effendi - McCoy Tyner/Effendi - McCoy Tyner_7_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/Effendi - McCoy Tyner/Effendi - McCoy Tyner_8_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/Effendi - McCoy Tyner/Effendi - McCoy Tyner_9_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/Effendi - McCoy Tyner/Effendi - McCoy Tyner_10_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/Effendi - McCoy Tyner/Effendi - McCoy Tyner_11_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/Effendi - McCoy Tyner/Effendi - McCoy Tyner_12_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/Effendi - McCoy Tyner/Effendi - McCoy Tyner_13_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/Effendi - McCoy Tyner/Effendi - McCoy Tyner_14_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/Effendi - McCoy Tyner/Effendi - McCoy Tyner_15_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/Effendi - McCoy Tyner/Effendi - McCoy Tyner_16_oc.wav
# /Users/Iman/Desktop/models/predict/original_jazz/classical/wav/Falling Grace .wav
# exporting /Users/Iman/Desktop/models/predict/songs/Falling Grace /Falling Grace _0_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/Falling Grace /Falling Grace _1_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/Falling Grace /Falling Grace _2_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/Falling Grace /Falling Grace _3_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/Falling Grace /Falling Grace _4_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/Falling Grace /Falling Grace _5_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/Falling Grace /Falling Grace _6_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/Falling Grace /Falling Grace _7_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/Falling Grace /Falling Grace _8_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/Falling Grace /Falling Grace _9_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/Falling Grace /Falling Grace _10_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/Falling Grace /Falling Grace _11_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/Falling Grace /Falling Grace _12_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/Falling Grace /Falling Grace _13_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/Falling Grace /Falling Grace _14_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/Falling Grace /Falling Grace _15_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/Falling Grace /Falling Grace _16_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/Falling Grace /Falling Grace _17_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/Falling Grace /Falling Grace _18_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/Falling Grace /Falling Grace _19_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/Falling Grace /Falling Grace _20_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/Falling Grace /Falling Grace _21_oc.wav
# /Users/Iman/Desktop/models/predict/original_jazz/classical/wav/INVITATION.wav
# exporting /Users/Iman/Desktop/models/predict/songs/INVITATION/INVITATION_0_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/INVITATION/INVITATION_1_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/INVITATION/INVITATION_2_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/INVITATION/INVITATION_3_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/INVITATION/INVITATION_4_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/INVITATION/INVITATION_5_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/INVITATION/INVITATION_6_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/INVITATION/INVITATION_7_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/INVITATION/INVITATION_8_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/INVITATION/INVITATION_9_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/INVITATION/INVITATION_10_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/INVITATION/INVITATION_11_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/INVITATION/INVITATION_12_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/INVITATION/INVITATION_13_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/INVITATION/INVITATION_14_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/INVITATION/INVITATION_15_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/INVITATION/INVITATION_16_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/INVITATION/INVITATION_17_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/INVITATION/INVITATION_18_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/INVITATION/INVITATION_19_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/INVITATION/INVITATION_20_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/INVITATION/INVITATION_21_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/INVITATION/INVITATION_22_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/INVITATION/INVITATION_23_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/INVITATION/INVITATION_24_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/INVITATION/INVITATION_25_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/INVITATION/INVITATION_26_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/INVITATION/INVITATION_27_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/INVITATION/INVITATION_28_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/INVITATION/INVITATION_29_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/INVITATION/INVITATION_30_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/INVITATION/INVITATION_31_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/INVITATION/INVITATION_32_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/INVITATION/INVITATION_33_oc.wav
# /Users/Iman/Desktop/models/predict/original_jazz/classical/wav/My Romance.wav
# exporting /Users/Iman/Desktop/models/predict/songs/My Romance/My Romance_0_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/My Romance/My Romance_1_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/My Romance/My Romance_2_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/My Romance/My Romance_3_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/My Romance/My Romance_4_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/My Romance/My Romance_5_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/My Romance/My Romance_6_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/My Romance/My Romance_7_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/My Romance/My Romance_8_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/My Romance/My Romance_9_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/My Romance/My Romance_10_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/My Romance/My Romance_11_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/My Romance/My Romance_12_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/My Romance/My Romance_13_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/My Romance/My Romance_14_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/My Romance/My Romance_15_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/My Romance/My Romance_16_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/My Romance/My Romance_17_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/My Romance/My Romance_18_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/My Romance/My Romance_19_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/My Romance/My Romance_20_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/My Romance/My Romance_21_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/My Romance/My Romance_22_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/My Romance/My Romance_23_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/My Romance/My Romance_24_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/My Romance/My Romance_25_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/My Romance/My Romance_26_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/My Romance/My Romance_27_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/My Romance/My Romance_28_oc.wav
# /Users/Iman/Desktop/models/predict/original_jazz/classical/wav/NoMoreBlues.wav
# exporting /Users/Iman/Desktop/models/predict/songs/NoMoreBlues/NoMoreBlues_0_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/NoMoreBlues/NoMoreBlues_1_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/NoMoreBlues/NoMoreBlues_2_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/NoMoreBlues/NoMoreBlues_3_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/NoMoreBlues/NoMoreBlues_4_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/NoMoreBlues/NoMoreBlues_5_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/NoMoreBlues/NoMoreBlues_6_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/NoMoreBlues/NoMoreBlues_7_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/NoMoreBlues/NoMoreBlues_8_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/NoMoreBlues/NoMoreBlues_9_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/NoMoreBlues/NoMoreBlues_10_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/NoMoreBlues/NoMoreBlues_11_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/NoMoreBlues/NoMoreBlues_12_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/NoMoreBlues/NoMoreBlues_13_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/NoMoreBlues/NoMoreBlues_14_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/NoMoreBlues/NoMoreBlues_15_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/NoMoreBlues/NoMoreBlues_16_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/NoMoreBlues/NoMoreBlues_17_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/NoMoreBlues/NoMoreBlues_18_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/NoMoreBlues/NoMoreBlues_19_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/NoMoreBlues/NoMoreBlues_20_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/NoMoreBlues/NoMoreBlues_21_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/NoMoreBlues/NoMoreBlues_22_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/NoMoreBlues/NoMoreBlues_23_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/NoMoreBlues/NoMoreBlues_24_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/NoMoreBlues/NoMoreBlues_25_oc.wav
# /Users/Iman/Desktop/models/predict/original_jazz/classical/wav/Remember - solo jazz piano.wav
# exporting /Users/Iman/Desktop/models/predict/songs/Remember - solo jazz piano/Remember - solo jazz piano_0_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/Remember - solo jazz piano/Remember - solo jazz piano_1_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/Remember - solo jazz piano/Remember - solo jazz piano_2_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/Remember - solo jazz piano/Remember - solo jazz piano_3_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/Remember - solo jazz piano/Remember - solo jazz piano_4_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/Remember - solo jazz piano/Remember - solo jazz piano_5_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/Remember - solo jazz piano/Remember - solo jazz piano_6_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/Remember - solo jazz piano/Remember - solo jazz piano_7_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/Remember - solo jazz piano/Remember - solo jazz piano_8_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/Remember - solo jazz piano/Remember - solo jazz piano_9_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/Remember - solo jazz piano/Remember - solo jazz piano_10_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/Remember - solo jazz piano/Remember - solo jazz piano_11_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/Remember - solo jazz piano/Remember - solo jazz piano_12_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/Remember - solo jazz piano/Remember - solo jazz piano_13_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/Remember - solo jazz piano/Remember - solo jazz piano_14_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/Remember - solo jazz piano/Remember - solo jazz piano_15_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/Remember - solo jazz piano/Remember - solo jazz piano_16_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/Remember - solo jazz piano/Remember - solo jazz piano_17_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/Remember - solo jazz piano/Remember - solo jazz piano_18_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/Remember - solo jazz piano/Remember - solo jazz piano_19_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/Remember - solo jazz piano/Remember - solo jazz piano_20_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/Remember - solo jazz piano/Remember - solo jazz piano_21_oc.wav
# /Users/Iman/Desktop/models/predict/original_jazz/classical/wav/Renewaltrio.wav
# exporting /Users/Iman/Desktop/models/predict/songs/Renewaltrio/Renewaltrio_0_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/Renewaltrio/Renewaltrio_1_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/Renewaltrio/Renewaltrio_2_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/Renewaltrio/Renewaltrio_3_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/Renewaltrio/Renewaltrio_4_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/Renewaltrio/Renewaltrio_5_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/Renewaltrio/Renewaltrio_6_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/Renewaltrio/Renewaltrio_7_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/Renewaltrio/Renewaltrio_8_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/Renewaltrio/Renewaltrio_9_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/Renewaltrio/Renewaltrio_10_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/Renewaltrio/Renewaltrio_11_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/Renewaltrio/Renewaltrio_12_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/Renewaltrio/Renewaltrio_13_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/Renewaltrio/Renewaltrio_14_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/Renewaltrio/Renewaltrio_15_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/Renewaltrio/Renewaltrio_16_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/Renewaltrio/Renewaltrio_17_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/Renewaltrio/Renewaltrio_18_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/Renewaltrio/Renewaltrio_19_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/Renewaltrio/Renewaltrio_20_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/Renewaltrio/Renewaltrio_21_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/Renewaltrio/Renewaltrio_22_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/Renewaltrio/Renewaltrio_23_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/Renewaltrio/Renewaltrio_24_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/Renewaltrio/Renewaltrio_25_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/Renewaltrio/Renewaltrio_26_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/Renewaltrio/Renewaltrio_27_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/Renewaltrio/Renewaltrio_28_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/Renewaltrio/Renewaltrio_29_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/Renewaltrio/Renewaltrio_30_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/Renewaltrio/Renewaltrio_31_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/Renewaltrio/Renewaltrio_32_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/Renewaltrio/Renewaltrio_33_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/Renewaltrio/Renewaltrio_34_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/Renewaltrio/Renewaltrio_35_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/Renewaltrio/Renewaltrio_36_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/Renewaltrio/Renewaltrio_37_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/Renewaltrio/Renewaltrio_38_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/Renewaltrio/Renewaltrio_39_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/Renewaltrio/Renewaltrio_40_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/Renewaltrio/Renewaltrio_41_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/Renewaltrio/Renewaltrio_42_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/Renewaltrio/Renewaltrio_43_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/Renewaltrio/Renewaltrio_44_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/Renewaltrio/Renewaltrio_45_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/Renewaltrio/Renewaltrio_46_oc.wav
# /Users/Iman/Desktop/models/predict/original_jazz/classical/wav/SammyWalked.wav
# exporting /Users/Iman/Desktop/models/predict/songs/SammyWalked/SammyWalked_0_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/SammyWalked/SammyWalked_1_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/SammyWalked/SammyWalked_2_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/SammyWalked/SammyWalked_3_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/SammyWalked/SammyWalked_4_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/SammyWalked/SammyWalked_5_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/SammyWalked/SammyWalked_6_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/SammyWalked/SammyWalked_7_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/SammyWalked/SammyWalked_8_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/SammyWalked/SammyWalked_9_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/SammyWalked/SammyWalked_10_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/SammyWalked/SammyWalked_11_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/SammyWalked/SammyWalked_12_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/SammyWalked/SammyWalked_13_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/SammyWalked/SammyWalked_14_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/SammyWalked/SammyWalked_15_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/SammyWalked/SammyWalked_16_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/SammyWalked/SammyWalked_17_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/SammyWalked/SammyWalked_18_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/SammyWalked/SammyWalked_19_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/SammyWalked/SammyWalked_20_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/SammyWalked/SammyWalked_21_oc.wav
# /Users/Iman/Desktop/models/predict/original_jazz/classical/wav/Speak Low (Doug McKenzie).wav
# exporting /Users/Iman/Desktop/models/predict/songs/Speak Low (Doug McKenzie)/Speak Low (Doug McKenzie)_0_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/Speak Low (Doug McKenzie)/Speak Low (Doug McKenzie)_1_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/Speak Low (Doug McKenzie)/Speak Low (Doug McKenzie)_2_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/Speak Low (Doug McKenzie)/Speak Low (Doug McKenzie)_3_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/Speak Low (Doug McKenzie)/Speak Low (Doug McKenzie)_4_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/Speak Low (Doug McKenzie)/Speak Low (Doug McKenzie)_5_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/Speak Low (Doug McKenzie)/Speak Low (Doug McKenzie)_6_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/Speak Low (Doug McKenzie)/Speak Low (Doug McKenzie)_7_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/Speak Low (Doug McKenzie)/Speak Low (Doug McKenzie)_8_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/Speak Low (Doug McKenzie)/Speak Low (Doug McKenzie)_9_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/Speak Low (Doug McKenzie)/Speak Low (Doug McKenzie)_10_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/Speak Low (Doug McKenzie)/Speak Low (Doug McKenzie)_11_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/Speak Low (Doug McKenzie)/Speak Low (Doug McKenzie)_12_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/Speak Low (Doug McKenzie)/Speak Low (Doug McKenzie)_13_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/Speak Low (Doug McKenzie)/Speak Low (Doug McKenzie)_14_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/Speak Low (Doug McKenzie)/Speak Low (Doug McKenzie)_15_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/Speak Low (Doug McKenzie)/Speak Low (Doug McKenzie)_16_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/Speak Low (Doug McKenzie)/Speak Low (Doug McKenzie)_17_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/Speak Low (Doug McKenzie)/Speak Low (Doug McKenzie)_18_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/Speak Low (Doug McKenzie)/Speak Low (Doug McKenzie)_19_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/Speak Low (Doug McKenzie)/Speak Low (Doug McKenzie)_20_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/Speak Low (Doug McKenzie)/Speak Low (Doug McKenzie)_21_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/Speak Low (Doug McKenzie)/Speak Low (Doug McKenzie)_22_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/Speak Low (Doug McKenzie)/Speak Low (Doug McKenzie)_23_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/Speak Low (Doug McKenzie)/Speak Low (Doug McKenzie)_24_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/Speak Low (Doug McKenzie)/Speak Low (Doug McKenzie)_25_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/Speak Low (Doug McKenzie)/Speak Low (Doug McKenzie)_26_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/Speak Low (Doug McKenzie)/Speak Low (Doug McKenzie)_27_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/Speak Low (Doug McKenzie)/Speak Low (Doug McKenzie)_28_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/Speak Low (Doug McKenzie)/Speak Low (Doug McKenzie)_29_oc.wav
# /Users/Iman/Desktop/models/predict/original_jazz/classical/wav/taketheatrain.wav
# exporting /Users/Iman/Desktop/models/predict/songs/taketheatrain/taketheatrain_0_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/taketheatrain/taketheatrain_1_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/taketheatrain/taketheatrain_2_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/taketheatrain/taketheatrain_3_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/taketheatrain/taketheatrain_4_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/taketheatrain/taketheatrain_5_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/taketheatrain/taketheatrain_6_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/taketheatrain/taketheatrain_7_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/taketheatrain/taketheatrain_8_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/taketheatrain/taketheatrain_9_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/taketheatrain/taketheatrain_10_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/taketheatrain/taketheatrain_11_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/taketheatrain/taketheatrain_12_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/taketheatrain/taketheatrain_13_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/taketheatrain/taketheatrain_14_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/taketheatrain/taketheatrain_15_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/taketheatrain/taketheatrain_16_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/taketheatrain/taketheatrain_17_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/taketheatrain/taketheatrain_18_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/taketheatrain/taketheatrain_19_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/taketheatrain/taketheatrain_20_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/taketheatrain/taketheatrain_21_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/taketheatrain/taketheatrain_22_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/taketheatrain/taketheatrain_23_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/taketheatrain/taketheatrain_24_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/taketheatrain/taketheatrain_25_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/taketheatrain/taketheatrain_26_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/taketheatrain/taketheatrain_27_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/taketheatrain/taketheatrain_28_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/taketheatrain/taketheatrain_29_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/taketheatrain/taketheatrain_30_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/taketheatrain/taketheatrain_31_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/taketheatrain/taketheatrain_32_oc.wav
# /Users/Iman/Desktop/models/predict/original_jazz/classical/wav/Very Early solo piano.wav
# exporting /Users/Iman/Desktop/models/predict/songs/Very Early solo piano/Very Early solo piano_0_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/Very Early solo piano/Very Early solo piano_1_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/Very Early solo piano/Very Early solo piano_2_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/Very Early solo piano/Very Early solo piano_3_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/Very Early solo piano/Very Early solo piano_4_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/Very Early solo piano/Very Early solo piano_5_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/Very Early solo piano/Very Early solo piano_6_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/Very Early solo piano/Very Early solo piano_7_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/Very Early solo piano/Very Early solo piano_8_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/Very Early solo piano/Very Early solo piano_9_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/Very Early solo piano/Very Early solo piano_10_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/Very Early solo piano/Very Early solo piano_11_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/Very Early solo piano/Very Early solo piano_12_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/Very Early solo piano/Very Early solo piano_13_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/Very Early solo piano/Very Early solo piano_14_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/Very Early solo piano/Very Early solo piano_15_oc.wav
# /Users/Iman/Desktop/models/predict/original_jazz/classical/wav/Warmvalleysolo.wav
# exporting /Users/Iman/Desktop/models/predict/songs/Warmvalleysolo/Warmvalleysolo_0_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/Warmvalleysolo/Warmvalleysolo_1_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/Warmvalleysolo/Warmvalleysolo_2_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/Warmvalleysolo/Warmvalleysolo_3_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/Warmvalleysolo/Warmvalleysolo_4_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/Warmvalleysolo/Warmvalleysolo_5_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/Warmvalleysolo/Warmvalleysolo_6_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/Warmvalleysolo/Warmvalleysolo_7_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/Warmvalleysolo/Warmvalleysolo_8_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/Warmvalleysolo/Warmvalleysolo_9_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/Warmvalleysolo/Warmvalleysolo_10_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/Warmvalleysolo/Warmvalleysolo_11_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/Warmvalleysolo/Warmvalleysolo_12_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/Warmvalleysolo/Warmvalleysolo_13_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/Warmvalleysolo/Warmvalleysolo_14_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/Warmvalleysolo/Warmvalleysolo_15_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/Warmvalleysolo/Warmvalleysolo_16_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/Warmvalleysolo/Warmvalleysolo_17_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/Warmvalleysolo/Warmvalleysolo_18_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/Warmvalleysolo/Warmvalleysolo_19_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/Warmvalleysolo/Warmvalleysolo_20_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/Warmvalleysolo/Warmvalleysolo_21_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/Warmvalleysolo/Warmvalleysolo_22_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/Warmvalleysolo/Warmvalleysolo_23_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/Warmvalleysolo/Warmvalleysolo_24_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/Warmvalleysolo/Warmvalleysolo_25_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/Warmvalleysolo/Warmvalleysolo_26_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/Warmvalleysolo/Warmvalleysolo_27_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/Warmvalleysolo/Warmvalleysolo_28_oc.wav
# /Users/Iman/Desktop/models/predict/original_jazz/classical/wav/WhyDoILoveYou.wav
# exporting /Users/Iman/Desktop/models/predict/songs/WhyDoILoveYou/WhyDoILoveYou_0_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/WhyDoILoveYou/WhyDoILoveYou_1_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/WhyDoILoveYou/WhyDoILoveYou_2_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/WhyDoILoveYou/WhyDoILoveYou_3_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/WhyDoILoveYou/WhyDoILoveYou_4_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/WhyDoILoveYou/WhyDoILoveYou_5_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/WhyDoILoveYou/WhyDoILoveYou_6_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/WhyDoILoveYou/WhyDoILoveYou_7_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/WhyDoILoveYou/WhyDoILoveYou_8_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/WhyDoILoveYou/WhyDoILoveYou_9_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/WhyDoILoveYou/WhyDoILoveYou_10_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/WhyDoILoveYou/WhyDoILoveYou_11_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/WhyDoILoveYou/WhyDoILoveYou_12_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/WhyDoILoveYou/WhyDoILoveYou_13_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/WhyDoILoveYou/WhyDoILoveYou_14_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/WhyDoILoveYou/WhyDoILoveYou_15_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/WhyDoILoveYou/WhyDoILoveYou_16_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/WhyDoILoveYou/WhyDoILoveYou_17_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/WhyDoILoveYou/WhyDoILoveYou_18_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/WhyDoILoveYou/WhyDoILoveYou_19_oc.wav
# /Users/Iman/Desktop/models/predict/original_jazz/classical/wav/xmas.wav
# exporting /Users/Iman/Desktop/models/predict/songs/xmas/xmas_0_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/xmas/xmas_1_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/xmas/xmas_2_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/xmas/xmas_3_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/xmas/xmas_4_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/xmas/xmas_5_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/xmas/xmas_6_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/xmas/xmas_7_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/xmas/xmas_8_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/xmas/xmas_9_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/xmas/xmas_10_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/xmas/xmas_11_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/xmas/xmas_12_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/xmas/xmas_13_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/xmas/xmas_14_oc.wav
# /Users/Iman/Desktop/models/predict/original_jazz/classical/wav/YBSN2CH2.wav
# exporting /Users/Iman/Desktop/models/predict/songs/YBSN2CH2/YBSN2CH2_0_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/YBSN2CH2/YBSN2CH2_1_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/YBSN2CH2/YBSN2CH2_2_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/YBSN2CH2/YBSN2CH2_3_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/YBSN2CH2/YBSN2CH2_4_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/YBSN2CH2/YBSN2CH2_5_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/YBSN2CH2/YBSN2CH2_6_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/YBSN2CH2/YBSN2CH2_7_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/YBSN2CH2/YBSN2CH2_8_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/YBSN2CH2/YBSN2CH2_9_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/YBSN2CH2/YBSN2CH2_10_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/YBSN2CH2/YBSN2CH2_11_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/YBSN2CH2/YBSN2CH2_12_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/YBSN2CH2/YBSN2CH2_13_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/YBSN2CH2/YBSN2CH2_14_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/YBSN2CH2/YBSN2CH2_15_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/YBSN2CH2/YBSN2CH2_16_oc.wav
# /Users/Iman/Desktop/models/predict/original_jazz/classical/wav/Zingaro - Jobim.wav
# exporting /Users/Iman/Desktop/models/predict/songs/Zingaro - Jobim/Zingaro - Jobim_0_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/Zingaro - Jobim/Zingaro - Jobim_1_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/Zingaro - Jobim/Zingaro - Jobim_2_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/Zingaro - Jobim/Zingaro - Jobim_3_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/Zingaro - Jobim/Zingaro - Jobim_4_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/Zingaro - Jobim/Zingaro - Jobim_5_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/Zingaro - Jobim/Zingaro - Jobim_6_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/Zingaro - Jobim/Zingaro - Jobim_7_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/Zingaro - Jobim/Zingaro - Jobim_8_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/Zingaro - Jobim/Zingaro - Jobim_9_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/Zingaro - Jobim/Zingaro - Jobim_10_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/Zingaro - Jobim/Zingaro - Jobim_11_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/Zingaro - Jobim/Zingaro - Jobim_12_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/Zingaro - Jobim/Zingaro - Jobim_13_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/Zingaro - Jobim/Zingaro - Jobim_14_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/Zingaro - Jobim/Zingaro - Jobim_15_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/Zingaro - Jobim/Zingaro - Jobim_16_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/Zingaro - Jobim/Zingaro - Jobim_17_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/Zingaro - Jobim/Zingaro - Jobim_18_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/Zingaro - Jobim/Zingaro - Jobim_19_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/Zingaro - Jobim/Zingaro - Jobim_20_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/Zingaro - Jobim/Zingaro - Jobim_21_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/Zingaro - Jobim/Zingaro - Jobim_22_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/Zingaro - Jobim/Zingaro - Jobim_23_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/Zingaro - Jobim/Zingaro - Jobim_24_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/Zingaro - Jobim/Zingaro - Jobim_25_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/Zingaro - Jobim/Zingaro - Jobim_26_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/Zingaro - Jobim/Zingaro - Jobim_27_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/Zingaro - Jobim/Zingaro - Jobim_28_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/Zingaro - Jobim/Zingaro - Jobim_29_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/Zingaro - Jobim/Zingaro - Jobim_30_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/Zingaro - Jobim/Zingaro - Jobim_31_oc.wav
# /Users/Iman/Desktop/models/predict/original_jazz/jazz/wav/alfiepno.wav
# exporting /Users/Iman/Desktop/models/predict/songs/alfiepno/alfiepno_0_oj.wav
# exporting /Users/Iman/Desktop/models/predict/songs/alfiepno/alfiepno_1_oj.wav
# exporting /Users/Iman/Desktop/models/predict/songs/alfiepno/alfiepno_2_oj.wav
# exporting /Users/Iman/Desktop/models/predict/songs/alfiepno/alfiepno_3_oj.wav
# exporting /Users/Iman/Desktop/models/predict/songs/alfiepno/alfiepno_4_oj.wav
# exporting /Users/Iman/Desktop/models/predict/songs/alfiepno/alfiepno_5_oj.wav
# exporting /Users/Iman/Desktop/models/predict/songs/alfiepno/alfiepno_6_oj.wav
# exporting /Users/Iman/Desktop/models/predict/songs/alfiepno/alfiepno_7_oj.wav
# exporting /Users/Iman/Desktop/models/predict/songs/alfiepno/alfiepno_8_oj.wav
# exporting /Users/Iman/Desktop/models/predict/songs/alfiepno/alfiepno_9_oj.wav
# exporting /Users/Iman/Desktop/models/predict/songs/alfiepno/alfiepno_10_oj.wav
# exporting /Users/Iman/Desktop/models/predict/songs/alfiepno/alfiepno_11_oj.wav
# exporting /Users/Iman/Desktop/models/predict/songs/alfiepno/alfiepno_12_oj.wav
# exporting /Users/Iman/Desktop/models/predict/songs/alfiepno/alfiepno_13_oj.wav
# exporting /Users/Iman/Desktop/models/predict/songs/alfiepno/alfiepno_14_oj.wav
# exporting /Users/Iman/Desktop/models/predict/songs/alfiepno/alfiepno_15_oj.wav
# exporting /Users/Iman/Desktop/models/predict/songs/alfiepno/alfiepno_16_oj.wav
# exporting /Users/Iman/Desktop/models/predict/songs/alfiepno/alfiepno_17_oj.wav
# exporting /Users/Iman/Desktop/models/predict/songs/alfiepno/alfiepno_18_oj.wav
# exporting /Users/Iman/Desktop/models/predict/songs/alfiepno/alfiepno_19_oj.wav
# exporting /Users/Iman/Desktop/models/predict/songs/alfiepno/alfiepno_20_oj.wav
# exporting /Users/Iman/Desktop/models/predict/songs/alfiepno/alfiepno_21_oj.wav
# exporting /Users/Iman/Desktop/models/predict/songs/alfiepno/alfiepno_22_oj.wav
# exporting /Users/Iman/Desktop/models/predict/songs/alfiepno/alfiepno_23_oj.wav
# exporting /Users/Iman/Desktop/models/predict/songs/alfiepno/alfiepno_24_oj.wav
# exporting /Users/Iman/Desktop/models/predict/songs/alfiepno/alfiepno_25_oj.wav
# ...
# exporting /Users/Iman/Desktop/models/predict/songs/UENO01/UENO01_15_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/UENO01/UENO01_16_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/UENO01/UENO01_17_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/UENO01/UENO01_18_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/UENO01/UENO01_19_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/UENO01/UENO01_20_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/UENO01/UENO01_21_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/UENO01/UENO01_22_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/UENO01/UENO01_23_oc.wav
# /Users/Iman/Desktop/models/predict/original_classical/classical/wav/victoria03.wav
# exporting /Users/Iman/Desktop/models/predict/songs/victoria03/victoria03_0_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/victoria03/victoria03_1_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/victoria03/victoria03_2_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/victoria03/victoria03_3_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/victoria03/victoria03_4_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/victoria03/victoria03_5_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/victoria03/victoria03_6_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/victoria03/victoria03_7_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/victoria03/victoria03_8_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/victoria03/victoria03_9_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/victoria03/victoria03_10_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/victoria03/victoria03_11_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/victoria03/victoria03_12_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/victoria03/victoria03_13_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/victoria03/victoria03_14_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/victoria03/victoria03_15_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/victoria03/victoria03_16_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/victoria03/victoria03_17_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/victoria03/victoria03_18_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/victoria03/victoria03_19_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/victoria03/victoria03_20_oc.wav
# /Users/Iman/Desktop/models/predict/original_classical/classical/wav/waldstein_1_format0.wav
# exporting /Users/Iman/Desktop/models/predict/songs/waldstein_1_format0/waldstein_1_format0_0_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/waldstein_1_format0/waldstein_1_format0_1_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/waldstein_1_format0/waldstein_1_format0_2_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/waldstein_1_format0/waldstein_1_format0_3_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/waldstein_1_format0/waldstein_1_format0_4_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/waldstein_1_format0/waldstein_1_format0_5_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/waldstein_1_format0/waldstein_1_format0_6_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/waldstein_1_format0/waldstein_1_format0_7_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/waldstein_1_format0/waldstein_1_format0_8_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/waldstein_1_format0/waldstein_1_format0_9_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/waldstein_1_format0/waldstein_1_format0_10_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/waldstein_1_format0/waldstein_1_format0_11_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/waldstein_1_format0/waldstein_1_format0_12_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/waldstein_1_format0/waldstein_1_format0_13_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/waldstein_1_format0/waldstein_1_format0_14_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/waldstein_1_format0/waldstein_1_format0_15_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/waldstein_1_format0/waldstein_1_format0_16_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/waldstein_1_format0/waldstein_1_format0_17_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/waldstein_1_format0/waldstein_1_format0_18_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/waldstein_1_format0/waldstein_1_format0_19_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/waldstein_1_format0/waldstein_1_format0_20_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/waldstein_1_format0/waldstein_1_format0_21_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/waldstein_1_format0/waldstein_1_format0_22_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/waldstein_1_format0/waldstein_1_format0_23_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/waldstein_1_format0/waldstein_1_format0_24_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/waldstein_1_format0/waldstein_1_format0_25_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/waldstein_1_format0/waldstein_1_format0_26_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/waldstein_1_format0/waldstein_1_format0_27_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/waldstein_1_format0/waldstein_1_format0_28_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/waldstein_1_format0/waldstein_1_format0_29_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/waldstein_1_format0/waldstein_1_format0_30_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/waldstein_1_format0/waldstein_1_format0_31_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/waldstein_1_format0/waldstein_1_format0_32_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/waldstein_1_format0/waldstein_1_format0_33_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/waldstein_1_format0/waldstein_1_format0_34_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/waldstein_1_format0/waldstein_1_format0_35_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/waldstein_1_format0/waldstein_1_format0_36_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/waldstein_1_format0/waldstein_1_format0_37_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/waldstein_1_format0/waldstein_1_format0_38_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/waldstein_1_format0/waldstein_1_format0_39_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/waldstein_1_format0/waldstein_1_format0_40_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/waldstein_1_format0/waldstein_1_format0_41_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/waldstein_1_format0/waldstein_1_format0_42_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/waldstein_1_format0/waldstein_1_format0_43_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/waldstein_1_format0/waldstein_1_format0_44_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/waldstein_1_format0/waldstein_1_format0_45_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/waldstein_1_format0/waldstein_1_format0_46_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/waldstein_1_format0/waldstein_1_format0_47_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/waldstein_1_format0/waldstein_1_format0_48_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/waldstein_1_format0/waldstein_1_format0_49_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/waldstein_1_format0/waldstein_1_format0_50_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/waldstein_1_format0/waldstein_1_format0_51_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/waldstein_1_format0/waldstein_1_format0_52_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/waldstein_1_format0/waldstein_1_format0_53_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/waldstein_1_format0/waldstein_1_format0_54_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/waldstein_1_format0/waldstein_1_format0_55_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/waldstein_1_format0/waldstein_1_format0_56_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/waldstein_1_format0/waldstein_1_format0_57_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/waldstein_1_format0/waldstein_1_format0_58_oc.wav
# /Users/Iman/Desktop/models/predict/original_classical/classical/wav/YOO01.wav
# exporting /Users/Iman/Desktop/models/predict/songs/YOO01/YOO01_0_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/YOO01/YOO01_1_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/YOO01/YOO01_2_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/YOO01/YOO01_3_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/YOO01/YOO01_4_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/YOO01/YOO01_5_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/YOO01/YOO01_6_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/YOO01/YOO01_7_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/YOO01/YOO01_8_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/YOO01/YOO01_9_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/YOO01/YOO01_10_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/YOO01/YOO01_11_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/YOO01/YOO01_12_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/YOO01/YOO01_13_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/YOO01/YOO01_14_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/YOO01/YOO01_15_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/YOO01/YOO01_16_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/YOO01/YOO01_17_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/YOO01/YOO01_18_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/YOO01/YOO01_19_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/YOO01/YOO01_20_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/YOO01/YOO01_21_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/YOO01/YOO01_22_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/YOO01/YOO01_23_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/YOO01/YOO01_24_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/YOO01/YOO01_25_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/YOO01/YOO01_26_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/YOO01/YOO01_27_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/YOO01/YOO01_28_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/YOO01/YOO01_29_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/YOO01/YOO01_30_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/YOO01/YOO01_31_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/YOO01/YOO01_32_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/YOO01/YOO01_33_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/YOO01/YOO01_34_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/YOO01/YOO01_35_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/YOO01/YOO01_36_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/YOO01/YOO01_37_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/YOO01/YOO01_38_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/YOO01/YOO01_39_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/YOO01/YOO01_40_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/YOO01/YOO01_41_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/YOO01/YOO01_42_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/YOO01/YOO01_43_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/YOO01/YOO01_44_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/YOO01/YOO01_45_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/YOO01/YOO01_46_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/YOO01/YOO01_47_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/YOO01/YOO01_48_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/YOO01/YOO01_49_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/YOO01/YOO01_50_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/YOO01/YOO01_51_oc.wav
# /Users/Iman/Desktop/models/predict/original_classical/classical/wav/ZHOU01.wav
# exporting /Users/Iman/Desktop/models/predict/songs/ZHOU01/ZHOU01_0_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/ZHOU01/ZHOU01_1_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/ZHOU01/ZHOU01_2_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/ZHOU01/ZHOU01_3_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/ZHOU01/ZHOU01_4_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/ZHOU01/ZHOU01_5_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/ZHOU01/ZHOU01_6_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/ZHOU01/ZHOU01_7_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/ZHOU01/ZHOU01_8_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/ZHOU01/ZHOU01_9_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/ZHOU01/ZHOU01_10_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/ZHOU01/ZHOU01_11_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/ZHOU01/ZHOU01_12_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/ZHOU01/ZHOU01_13_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/ZHOU01/ZHOU01_14_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/ZHOU01/ZHOU01_15_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/ZHOU01/ZHOU01_16_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/ZHOU01/ZHOU01_17_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/ZHOU01/ZHOU01_18_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/ZHOU01/ZHOU01_19_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/ZHOU01/ZHOU01_20_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/ZHOU01/ZHOU01_21_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/ZHOU01/ZHOU01_22_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/ZHOU01/ZHOU01_23_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/ZHOU01/ZHOU01_24_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/ZHOU01/ZHOU01_25_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/ZHOU01/ZHOU01_26_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/ZHOU01/ZHOU01_27_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/ZHOU01/ZHOU01_28_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/ZHOU01/ZHOU01_29_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/ZHOU01/ZHOU01_30_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/ZHOU01/ZHOU01_31_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/ZHOU01/ZHOU01_32_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/ZHOU01/ZHOU01_33_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/ZHOU01/ZHOU01_34_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/ZHOU01/ZHOU01_35_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/ZHOU01/ZHOU01_36_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/ZHOU01/ZHOU01_37_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/ZHOU01/ZHOU01_38_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/ZHOU01/ZHOU01_39_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/ZHOU01/ZHOU01_40_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/ZHOU01/ZHOU01_41_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/ZHOU01/ZHOU01_42_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/ZHOU01/ZHOU01_43_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/ZHOU01/ZHOU01_44_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/ZHOU01/ZHOU01_45_oc.wav
# exporting /Users/Iman/Desktop/models/predict/songs/ZHOU01/ZHOU01_46_oc.wav

# %%
# myaudio = AudioSegment.from_wav("/Users/Iman/Desktop/models/predict/original/classical/waldstein_1_format0.mid.wav")
# chunk_length_ms = 10000 # pydub calculates in millisec
# chunks = make_chunks(myaudio, chunk_length_ms) #Make chunks of one sec

# #Export all of the individual chunks as wav files

# for i, chunk in enumerate(chunks):
#     chunk_name = "{0}".format(i) + ".mid.wav"
#     print "exporting", chunk_name
# #         chunk.export(chunk_name, format="wav")
